# %%
# Cristian Alejandro Nolasco Vargas
# AL07264144
# 10/09/2026
# Menu Modular para acceder a diferentes funciones.

# Función para las tuplas
def opcionTupla ():
    print("\n__________ Mostrar tupla ordenada _________\n")
    numeros = (5, 76, 23, 45, 67, 23, 98, 3, 8)
    print(f"El tercer elemento de la tupla es: {numeros[2]}")
        
    newNumero1 = float(input("Ingresa el Primer Nuevo Número: "))
    newNumero2 = float(input("Ingresa el Segundo Nuevo Número: "))
        
    nueva_tupla = numeros + (newNumero1, newNumero2)
    lista_numeros = list(nueva_tupla)                
    lista_numeros.sort()
    print(f"Lista ordenada: {lista_numeros}")
    
    return nueva_tupla

def sumaTupla (tupla):
    sumaTotal = 0
    for i in range(0, len(tupla)):
        sumaTotal += tupla[i]
    return sumaTotal

# Función para uso de diccionarios
def opcionDiccionario ():
    print("\n_______ Buscar telefono ______\n")
                
    contactos = {
        "juan": "342 2344 2344",
        "nose": "943 2345 9822",
        "cr7": "242 8092 8493",
        "messi": "243 7654 3534"
    }
    
    nombre = input("Ingresa el nombre del nuevo contacto: ").lower()
    numero = input("Ingresa su numero: ")

    contactos[nombre] = numero
    
    print("Lista de contacto")
    for c in contactos.keys():
        print(f"--{c}")
    
    nombre = input("Ingresa Nombre a Buscar: ")
    
    return nombre,contactos

def buscarTelefono(contactos, nombre):
    telefono = contactos.get(nombre, "Contacto no encontrado")
    return telefono

# funcion try-except
def opcionTryExcept():
    print("\n_________ Suma dos Números _________\n")
    # Ciclo para pedir varias veces si se llega a cometer un error
    while True:
        # Primer try-except para controlar si no se ingrese un entero
        try:
            num1 = int(input("Ingrese el primer numero entero: "))
            num2 = int(input("Ingresa el segundo numero entero: "))
            
            # Segundo try-except para conocer si se ingreso un cero
            try:
                divicion = num1 / num2      
                divicion = num2 / num1 
                    
                suma = num1 + num2
                print(f"La suma del los numeros: {suma}")    
                break
            except ZeroDivisionError:
                print("----Ingresa un numero diferente a cero para realizar la suma correctamente----") 
        except:
            print("Se ha ingresado un número incorrecto")   
                    
# función para uso de strings
def opcionString():
    print("\n_________ Analizar Mensaje __________\n")
    mensaje = input("Escribe un mensaje: ")
    
    count_mensaje = len(mensaje)
    mayus_mensaje = mensaje.upper()
    replace_mensaje = mensaje.replace("hola", "(Palabra encriptada)")

    print(f"Mensaje Original: {mensaje} - Longitud: {count_mensaje}")
    print(f"mensaje UPPER: {mayus_mensaje}")
    
    return replace_mensaje

def countPalabras(frase):
    count_mensaje_replace = frase.split()
    total_palabras_replace = len(count_mensaje_replace)
    return total_palabras_replace

# Función mostrar menu
def mostrarMenu():
    print("\n================== Menu Modular de todo los visto ======================\n")
    print("1) Mostrar tupla ordenada")
    print("2) Buscar telefono")
    print("3) Suma dos Números")
    print("4) Analizar mensaje")
    print("5) Finalizar el programa")
    print("\n========================================")

# Ciclo para selecciones de multiples opciónes
while True:

    # Uso Funcion mostrar Menu
    mostrarMenu()
    
    opcion = int(input("Opción: "))
    
    # Estructura selección de opcion
    match opcion:
        # Caso 1: uso de tuplas
        case 1:
            nueva_tupla = opcionTupla()
            # Uso de la funcion pedida para las tuplas
            suma = sumaTupla(nueva_tupla)
            print(f"La suma de los numeros en la tupla: {suma}")
        
        # Caso 2: uso de diccionarios       
        case 2:
            nombre,contactos = opcionDiccionario()
            # Uso de la funcion para diccionarios
            busqueda_telefono = buscarTelefono(contactos,nombre.lower())
            print(f"\nEl teléfono {nombre} es: {busqueda_telefono}")

        # Caso 3: uso try-except
        case 3:
            opcionTryExcept()
        
        # Caso 4: uso de strings     
        case 4:
            replace_mensaje = opcionString()
            total_palabras_replace = countPalabras(replace_mensaje)
            
            print(f"mensaje con Remplazo: {replace_mensaje} - Cantidad Palabras: {total_palabras_replace}")
        
        # Finalización programa
        case 5:
            print("\n______________ Finalizando Programa, Gracias por su preferencia _______________________\n")
            break
        case _:
            print("-------------------------- Opción no valida ---------------------\n")
# Out:
# ================== Menu Modular de todo los visto ======================
#
# 1) Mostrar tupla ordenada
# 2) Buscar telefono
# 3) Suma dos Números
# 4) Analizar mensaje
# 5) Finalizar el programa
#
# ========================================
#
# __________ Mostrar tupla ordenada _________
#
# El tercer elemento de la tupla es: 23
# Lista ordenada: [3, 5, 8, 23, 23, 45, 67, 76, 78.0, 98, 894.0]
# La suma de los numeros en la tupla: 1320.0
#
# ================== Menu Modular de todo los visto ======================
#
# 1) Mostrar tupla ordenada
# 2) Buscar telefono
# 3) Suma dos Números
# 4) Analizar mensaje
# 5) Finalizar el programa
#
# ========================================
#
# _______ Buscar telefono ______
#
# Lista de contacto
# --juan
# --nose
# --cr7
# --messi
# --holasaludos
#
# El teléfono juan es: 342 2344 2344
#
# ================== Menu Modular de todo los visto ======================
#
# 1) Mostrar tupla ordenada
# 2) Buscar telefono
# 3) Suma dos Números
# 4) Analizar mensaje
# 5) Finalizar el programa
#
# ========================================
#
# _________ Suma dos Números _________
#
# Se ha ingresado un número incorrecto
# ----Ingresa un numero diferente a cero para realizar la suma correctamente----
# La suma del los numeros: 90
#
# ================== Menu Modular de todo los visto ======================
#
# 1) Mostrar tupla ordenada
# 2) Buscar telefono
# 3) Suma dos Números
# 4) Analizar mensaje
# 5) Finalizar el programa
#
# ========================================
#
# _________ Analizar Mensaje __________
#
# Mensaje Original: hola, nose saludos - Longitud: 18
# mensaje UPPER: HOLA, NOSE SALUDOS
# mensaje con Remplazo: (Palabra encriptada), nose saludos - Cantidad Palabras: 4
#
# ================== Menu Modular de todo los visto ======================
#
# 1) Mostrar tupla ordenada
# 2) Buscar telefono
# 3) Suma dos Números
# 4) Analizar mensaje
# 5) Finalizar el programa
#
# ========================================
#
# ______________ Finalizando Programa, Gracias por su preferencia _______________________
