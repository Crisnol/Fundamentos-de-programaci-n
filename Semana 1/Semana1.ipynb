# %% [markdown]
# # Sesión 1
# Este archivo es para 2 cosas:
# - Para familiarizarnos en Jupyter Notebook
# - Practicar python

# %%
print("Holo nose")
nose = input("¿Cuál es tu nombre? ")
print("Hola, " + nose + "!")
# Out:
# Holo nose
# Hola, messi!

# %% [markdown]
# ## Algoritmo para clacular velocidad

# %%
d = float(input("Ingrese la distaciaen km: "))
t = float(input("Ingrese el tiempo en horas: "))

velocidad = d/t

print("Tu velocidad es", velocidad)
# Out:
# Tu velocidad es 2.2857142857142856

# %% [markdown]
# ### Operadores

# %%
a = 89
b = 80

print(a==b)
print(a>b)
print(a!=b)
# Out:
# False
# True
# True

# %% [markdown]
# ### Saludo

# %%
name = input("Hola, como te llamas?")
age = int(input("Ingresa tu edad: "))

print(f"Hola {name}, tienes {age} años")
# Out:
# Hola crisnol, tienes 9 años
