# %% [markdown]
# # Ejercicios refuerzo semana 2

# %% [markdown]
# **Ejercicio 1: Mayor de edad**
#
# Enunciado: Crea un programa que pida la edad de una persona y muestre si es mayor de edad (18 años o más) o menor de edad. Entrada: 17 Salida: Eres menor de edad

# %%
age = int( input("Ingrese su edad:"))

if(age >= 18):
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %% [markdown]
# **Ejercicio 2: Número par o impar**
#
# Enunciado: Crea un programa que pida un número entero y determine si es par o impar usando el operador módulo %. Entrada: 7 Salida: 7 es un número impar

# %%
num = int(input("Ingresa un numero entero: "))

if(num % 2 == 0):
    print("Es un numero par")
else:
    print("Es impar")
# Out:
# Es un numero par

# %% [markdown]
# **Ejercicio 3: Calificación aprobatoria**
#
# Enunciado: Crea un programa que pida una calificación de 0 a 10 y muestre si la materia está aprobada (mayor o igual a 6) o reprobada. Entrada: 7 Salida: Aprobado

# %%
cal = float(input("Ingresa tu calificación (0-10): "))

if(cal >= 6):
    print("Esta aprobada")
else:
    print("Esta reprobada")
# Out:
# Esta reprobada

# %% [markdown]
# **Ejercicio 4: Clasificación por rango de edad con elif**
#
# Enunciado: Crea un programa que clasifique a una persona según su edad: menor de 3 años "Bebé", de 3 a 12 "Niño", de 13 a 17 "Adolescente" y de 18 en adelante "Adulto". Usa elif. Entrada: 15 Salida: Adolescente

# %%
age = int(input("Ingresa tu edad: "))

if(age >= 18):
    print("Adulto")
elif(age >= 13):
    print("Adolecentes")
elif(age >= 3):
    print("Niño")
else:
    print("Bebé")
# Out:
# Niño

# %% [markdown]
# **Ejercicio 5: Descuento por tipo de visitante**
#
# Enunciado: Crea un programa que pida el tipo de visitante (adulto_mayor, profesor, estudiante u otro) y calcule el precio de un boleto base de $45 aplicando solo un descuento: adulto mayor 12%, profesor 10%, estudiante 10%, otro 0%. Entrada: estudiante Salida: Precio final: $40.50

# %%
tipo_visitante = input("Ingrese que tipo de visitante es: ")
precio_boleto = 45

if(tipo_visitante == "adulto_mayor"):
    precio_final = precio_boleto * 0.88
elif(tipo_visitante == "profesor"):
    precio_final = precio_boleto * 0.90
elif(tipo_visitante == "estudiante"):
    precio_final = precio_boleto * 0.90
else:
    precio_final = precio_boleto

print(f"Total a pagar: {precio_final:.2f} ")
# Out:
# Total a pagar: 40.50

# %% [markdown]
# **Ejercicio 6: Acceso con operador and**
#
# Enunciado: Crea un programa que pida la edad y si la persona tiene credencial vigente (si/no). Solo se permite el acceso si la edad es mayor o igual a 18 y la credencial es si. Entrada: 20 y si Salida: Acceso permitido

# %%
age = int(input("Edad: "))
credencial = input("Crendencial vigente (si/no):" )

if(age >= 18):
    if(credencial == "si"):
        print("Acceso permitido")
    else:
        print("Acceso no permitido, credencial no vigente")
else:
    print("Necesitas ser mayor de edad")
# Out:
# Acceso no permitido, credencial no vigente

# %% [markdown]
# **Ejercicio 7: Detección de número negativo con or**
#
# Enunciado: Crea un programa que pida dos números y muestre una alerta si alguno de ellos es negativo, usando el operador or. Entrada: 5 y -3 Salida: Hay un número negativo

# %%
num1 = int(input("Número 1: " ))
num2 = int(input("Número 2: " ))

if(num1 > 0 or num2 > 0):
    print("Todos los numeros son positivos")
else:
    print("Hay un numero negativo")
# Out:
# Todos los numeros son positivos

# %% [markdown]
# **Ejercicio 8: Positivo y par con anidamiento**
#
# Enunciado: Crea un programa que pida un número entero y, si es positivo, verifique además si es par usando un if anidado. Entrada: 8 Salida: El número es positivo y par

# %%
num = int(input("Numero entero: "))

if(num > 0):
    if(num % 2 == 0 ):
        print("Tu numero es positivo y par")
    else:
        print("Tu numero es positivo y impar")
else:
    print("Tu numero es negativo")
# Out:
# Tu numero es negativo

# %% [markdown]
# **Ejercicio 9: Salir del proceso con not**
#
# Enunciado: Crea un programa que pregunte si desea continuar. Si la respuesta NO es si (usa el operador not), el proceso finaliza. Entrada: no Salida: Proceso finalizado

# %%
continuar = input("¿Deseas continuar? (si/no)")

if(not(continuar == "si")):
    print("Proceso finalizado")
# Out:
# Proceso finalizado

# %% [markdown]
# **Ejercicio 10: Contador del 1 al 5**
#
# Enunciado: Escribe un programa que imprima los números del 1 al 5 usando un ciclo while y una variable contador. Entrada: Ninguna. Salida:

# %%
i = 1

while (i <= 5):
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Ejercicio 11: Suma de los primeros N números**
#
# Enunciado: Crea un programa que pida un número entero positivo N y calcule con while la suma de los números del 1 al N. Entrada: 5 Salida: La suma del 1 al 5 es: 15

# %%
num = int(input("Ingrese un numero entero positivo: "))
i = 0
suma = 0

while (i <= num):
    suma = i + suma
    i += 1
print(f"La suma es: {suma}")
# Out:
# La suma es: 36

# %% [markdown]
# **Ejercicio 12: Tabla de multiplicar con while**
#
# Enunciado: Crea un programa que pida un número y muestre su tabla de multiplicar del 1 al 10 usando while. Entrada: 3 Salida:

# %%
num = int(input("Numero para la tabla de multiplicar: "))
count = 0
 
while(count < 10):
    count += 1
    mult = num * count
    print(f"{num} x {count} = {mult}")
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# **Ejercicio 13: Cuenta regresiva**
#
# Enunciado: Crea un programa que imprima los números del 5 al 1 con while y después el mensaje "Despegue". Entrada: Ninguna. Salida:

# %%
import time
i = 1

while (i <= 5):
    print(i)
    time.sleep(1) 
    i += 1
print("Despegue")
# Out:
# 1
# 2
# 3
# 4
# 5
# Despegue

# %% [markdown]
# **Ejercicio 14: Salir del ciclo con break**
#
# Enunciado: Crea un programa que capture textos con input() dentro de un while True. Si el usuario escribe salir, el ciclo se interrumpe con break. Entrada: hola, mundo, salir Salida:
