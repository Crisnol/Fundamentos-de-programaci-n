# %% [markdown]
# # Semana 2

# %% [markdown]
# #### if python

# %%
calificacion = 400
if calificacion >= 90:
    print("A")
elif(calificacion >= 80):
    print("B")
elif(calificacion >= 70):
    print("C")
elif(calificacion >= 60):
    print("D")
else:
    print("E")
# Out:
# A

# %% [markdown]
# #### Operadores logicos

# %%
PL1 = False
PL2 = True

print(PL1 and PL2)
# Out:
# False

# %%
edad = 65
tipo = "aulto_mayour"

es_mayor = edad >=18
aplica_descuento = (edad >=60) and (tipo == "adulto_mayor")
print(aplica_descuento)
# Out:
# False

# %%
edad = int(input("ingresa tu edad"))

if(edad< 0):
    print("No hay edades amnores a cero")
else:
    print("ahora si vamos a travajar con edades reales")
# Out:
# ahora si vamos a travajar con edades reales

# %%
precio = float(input("Precio: "))
tipo = "adulto_mayor"

if tipo == "adulto_mayor":
    descuento = precio * 0.12          
elif tipo == "profesor" or tipo == "estudiante":
    descuento = precio * 0.10         
else:
    descuento = 0


total = precio - descuento
print(f"Total a pagar: ${total:.2f}")
# Out:
# Total a pagar: $39.60
