# %% [markdown]
# # SEMANA 7 APUNTES

# %%
archivo = open("ola.txt", mode="a")
archivo.write("si se puede escribir desde python\n")
archivo.write("nose")
archivo.close()
print("Se escribio correctamente")
# Out:
# Se escribio correctamente

# %%
with open("bitacora.txt", "w") as archivo:
    archivo.write("primera linea\n")
    archivo.write("segunda linea\n")
    archivo.write("tercera linea\n")

with open("bitacora.txt", "a") as archivo:
    archivo.write("cuarta linea\n")

# %%
nombre = input("Ingresa tu nombre: ")
edad = input("Ingresa tu edad: ")

with open("datos_usuario.txt", "w") as archivo:
    archivo.write(f"Nombre: {nombre}, Edad: {edad}\n")

print("Datos guardados en datos_usuario.txt.")
# Out:
# Datos guardados en datos_usuario.txt.

# %% [markdown]
# ## LECTURA

# %%
with open("IDK.txt", mode= "r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# hola buenos dias
# esto es algo para leer
# slu2

# %%
with open("IDK.txt", "r") as archivo:
    linea1 = archivo.readline()
    linea2 = archivo.readline()

print("Primera linea:", linea1.strip())
print("Segunda linea:", linea2.strip())
# Out:
# Primera linea: hola buenos dias
#
# Segunda linea: esto es algo para leer

# %%
with open("IDK.txt", "r") as archivo:
    lineas = archivo.readlines()

print(lineas)

print("Total de lineas:", len(lineas))
for i, linea in enumerate(lineas, 1):
    print(f"{i}: {linea.strip()}")
# Out:
# ['hola buenos dias\n', 'esto es algo para leer\n', 'slu2']

# %%
with open("IDK.txt", "r") as archivo:
    for hola in archivo:
        print(hola.strip())
# Out:
# hola buenos dias
# esto es algo para leer
# slu2
