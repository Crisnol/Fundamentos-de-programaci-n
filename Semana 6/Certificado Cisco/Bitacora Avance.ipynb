# %% [markdown]
# # Bitácora de avance

# %% [markdown]
# ## Modulo 1 / Ejercicios interactivos y laboratorios / Examen Modulo
#
# ![alt text](image.png)
# ![alt text](image-8.png)
# ![alt text](image-1.png)
